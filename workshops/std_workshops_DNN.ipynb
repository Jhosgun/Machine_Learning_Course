# %% [markdown]
# ![pngtree-blue-technology-light-artificial-intelligence-cool-banner-background-material-picture-image_968735.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# #Workshop Tasks and Questions with MNIST Dataset (DNN Focus)

# %% [markdown]
# ##1.Task: Data Preprocessing
#
# Preprocess MNIST dataset for DNN training:
#
# - Normalize pixel values to the range [0, 1].
# - Flatten 28x28 images into 1D arrays for input to DNN.
# - Explore methods to handle grayscale images.
#
# Why is data normalization important in preparing MNIST data for DNN models?
#
# How does flattening images impact the representation of handwritten digits in DNN training?

# %% [markdown]
# ##2.Task: Building DNN Architecture
#
# Design a DNN architecture for MNIST digit classification:
#
# - Determine the number of layers and neurons per layer.
# - Select activation functions (e.g., ReLU, softmax) for hidden layers and output layer.
# - Define output layer configuration for multi-class classification (10 classes for digits 0-9).
#
#
# What factors influence the choice of activation functions in DNN architectures for MNIST digit classification?
#
# How can the number of hidden layers affect the DNN's ability to distinguish between different digits?

# %% [markdown]
# ##3.Task: Training and Optimization
#
# Train the DNN model using MNIST data:
#
# - Choose appropriate loss function (e.g., categorical cross-entropy) for multi-class classification.
# - Implement batch training with adjustable batch size and epochs.
# - Monitor training metrics (e.g., accuracy) and adjust hyperparameters (e.g., learning rate) as needed.
#
# How does the choice of loss function impact the DNN's ability to minimize classification errors in MNIST?
#
# What techniques can be employed to prevent overfitting during DNN training on the MNIST dataset?

# %% [markdown]
# ##4.Task: Evaluation and Metrics
#
# Evaluate DNN model performance using validation and test sets:
#
# - Calculate metrics such as accuracy, precision, recall, and F1-score.
# - Interpret evaluation results to gauge model effectiveness and areas for improvement.
#
# How would you interpret the precision and recall metrics for a DNN model achieving 95% accuracy on MNIST?
#
# Why is it important to use separate validation and test sets in evaluating DNN models?

# %% [markdown]
# ##5.Task: Model Optimization Strategies
#
# Optimize the DNN model's performance on MNIST:
#
# - Experiment with hyperparameters (e.g., learning rate, batch size) to improve training efficiency.
# - Apply regularization techniques (e.g., dropout) to enhance model generalization.
#
# How can adjusting the learning rate affect the convergence speed of a DNN model trained on MNIST?
#
# What benefits does dropout regularization provide in preventing overfitting in DNNs?

# %% [markdown]
# ##Accessing the MNIST Dataset

# %% [markdown]
# ###Using tensorflow

# %%
import tensorflow as tf
mnist = tf.keras.datasets.mnist
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# %%
#Ensure to reshape and normalize the pixel values:
x_train, x_test = x_train / 255.0, x_test / 255.0
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-fd15195286f5> in <cell line: 2>()
#       1 #Ensure to reshape and normalize the pixel values:
# ----> 2 x_train, x_test = x_train / 255.0, x_test / 255.0
#
# NameError: name 'x_train' is not defined

# %% [markdown]
# ###Using PyTorch

# %%
import torch
from torchvision import datasets, transforms
train_dataset = datasets.MNIST(root='./data', train=True, transform=transforms.ToTensor(), download=True)
test_dataset = datasets.MNIST(root='./data', train=False, transform=transforms.ToTensor())

# %%
#Load data into batches using DataLoader
train_loader = torch.utils.data.DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True)
test_loader = torch.utils.data.DataLoader(dataset=test_dataset, batch_size=batch_size, shuffle=False)

# %% [markdown]
# ![Diagrama sin título.drawio.jpg](data:image/jpeg;base64,...)
