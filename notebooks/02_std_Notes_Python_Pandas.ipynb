# %% [markdown]
# <img src="https://gitlab.com/bivl2ab/academico/cursos-uis/ai/ai-uis-student/raw/master/imgs/pandas_logo.png" alt="Drawing" style="width:900px;">
#
#
#
# # <center> 02. Pandas Introduction! </center>
#
#
#
# ## <span style="color:red"> Outline </span>
# 1. **Pandas Introduction**
# 2. **Pandas DataFrames and DataSeries**
# 3. **Plotting with matplotlib and pandas**
#
#
# ## <span style="color:red"> 1. Pandas Introduction </span>
#
# [*Pandas*](http://pandas.pydata.org/) is a column-oriented data analysis API that provides high-performance, easy-to-use data structures and data analysis.
#
# Among main pandas features, are:
# * Access and manipulate data within a `DataFrame` and `Series`  data structures
# * Allows import CSV data into a *pandas* `DataFrame`
# * Allows reindex a `DataFrame` to shuffle data
#
# ***see more tutorials at https://pandas.pydata.org/pandas-docs/stable/tutorials.html***

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
pd.__version__
# Out:
# '1.5.3'

# %% [markdown]
# ## <span style="color:green"> If you are in colaboratoy </span>:

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd drive/My Drive/ai-uis-student/notebooks
# !pwd
# Out:
# Mounted at /content/drive
# [Errno 2] No such file or directory: 'drive/My Drive/ai-uis-student/notebooks'
# /content
# /content

# %% [markdown]
# The main data structures in *pandas* are implemented as two classes:
#
#   * **`DataFrame`**, which you can imagine as a relational data table, with rows and named columns.
#   * **`Series`**, which is a single column. A `DataFrame` contains one or more `Series` and a name for each `Series`.
#
# ---
#
# ## <span style="color:red"> 2. DataFrame and series </span>
#
#
#
# The data frame is used for data manipulation like in [Spark](https://spark.apache.org/) and [R](https://www.r-project.org/about.html). `DataFrame` objects can be created by passing a `dict` mapping `string` column names to `Series` objects, for instance:

# %%
city_names = pd.Series(['Bucaramanga', 'Bogotá', 'Málaga'])
population = pd.Series([1524690, 10157850, 10000])

pd.DataFrame({ 'City name': city_names, 'Population': population })
# Out:
#      City name  Population
# 0  Bucaramanga     1524690
# 1       Bogotá    10157850
# 2       Málaga       10000

# %% [markdown]
# ## Loading and inspecting
#
# But typically the DataFrame load data from external entire files. The files can have millions of data that can be manipulated with pandas using Dataframes. For instance:

# %%
#california_housing_dataframe = pd.read_csv
#("https://storage.googleapis.com/mledu-datasets/california_housing_train.csv", sep=",")
d = pd.read_csv("../data/california_housing_train.csv")
type(d)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# DataFrame.head  displays the first few records of a DataFrame:

# %%
d.head(7)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
# 5    -114.58     33.63                29.0       1387.0           236.0
# 6    -114.58     33.61                25.0       2907.0           680.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0
# 5       671.0       239.0         3.3438             74000.0
# 6      1841.0       633.0         2.6768             82400.0

# %%
d.columns, d.shape
# Out:
# (Index([u'longitude', u'latitude', u'housing_median_age', u'total_rooms',
#         u'total_bedrooms', u'population', u'households', u'median_income',
#         u'median_house_value'],
#        dtype='object'), (17000, 9))

# %% [markdown]
# `DataFrame.describe` to show interesting statistics about a DataFrame

# %%
d.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  17000.000000  17000.000000        17000.000000  17000.000000
# mean    -119.562108     35.625225           28.589353   2643.664412
# std        2.005166      2.137340           12.586937   2179.947071
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.790000     33.930000           18.000000   1462.000000
# 50%     -118.490000     34.250000           29.000000   2127.000000
# 75%     -118.000000     37.720000           37.000000   3151.250000
# max     -114.310000     41.950000           52.000000  37937.000000
#
#        total_bedrooms    population    households  median_income  \
# count    17000.000000  17000.000000  17000.000000   17000.000000
# mean       539.410824   1429.573941    501.221941       3.883578
# std        421.499452   1147.852959    384.520841       1.908157
# min          1.000000      3.000000      1.000000       0.499900
# 25%        297.000000    790.000000    282.000000       2.566375
# 50%        434.000000   1167.000000    409.000000       3.544600
# 75%        648.250000   1721.000000    605.250000       4.767000
# max       6445.000000  35682.000000   6082.000000      15.000100
#
#        median_house_value
# count        17000.000000
# mean        207300.912353
# std         115983.764387
# min          14999.000000
# 25%         119400.000000
# 50%         180400.000000
# 75%         265000.000000
# max         500001.000000

# %% [markdown]
# A powerful feature of *pandas* is graphing. For example, `DataFrame.hist`  shows the distribution of values in a column

# %%
d.hist('housing_median_age')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f7a3df937d0>]], dtype=object)

# %%
d["median_house_value"].head()
# Out:
# 0    66900.0
# 1    80100.0
# 2    85700.0
# 3    73400.0
# 4    65500.0
# Name: median_house_value, dtype: float64

# %%
#acces to a specific range of data
d[1000:1015]
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 1000     -117.1     33.36                19.0       3518.0           658.0
# 1001     -117.1     33.17                12.0       2465.0           412.0
# 1002     -117.1     33.15                 5.0       3159.0           685.0
# 1003     -117.1     33.14                 7.0      10665.0          2576.0
# 1004     -117.1     33.12                12.0        961.0           342.0
# 1005     -117.1     33.00                 5.0      15502.0          2613.0
# 1006     -117.1     32.97                17.0       3167.0           861.0
# 1007     -117.1     32.96                 7.0       3619.0           770.0
# 1008     -117.1     32.90                16.0       2994.0           445.0
# 1009     -117.1     32.83                16.0       4214.0           744.0
# 1010     -117.1     32.77                49.0       4449.0           711.0
# 1011     -117.1     32.76                52.0       2606.0           426.0
# 1012     -117.1     32.76                31.0        987.0           267.0
# 1013     -117.1     32.76                30.0       1835.0           474.0
# 1014     -117.1     32.75                23.0       1858.0           551.0
#
#       population  households  median_income  median_house_value
# 1000      2091.0       610.0         3.2614            168800.0
# 1001      1226.0       428.0         5.4819            183800.0
# 1002      1398.0       581.0         3.1467            161100.0
# 1003      4917.0      2424.0         2.3171            159500.0
# 1004       315.0       201.0         0.8130            275000.0
# 1005      7417.0      2358.0         5.9094            261100.0
# 1006      2098.0       828.0         2.4459             85800.0
# 1007      1134.0       482.0         4.1279            167600.0
# 1008      1047.0       437.0         5.1490            184300.0
# 1009      1820.0       699.0         4.3783            179500.0
# 1010      1606.0       709.0         5.7768            281600.0
# 1011       883.0       380.0         4.2813            270800.0
# 1012       619.0       250.0         2.9286            151800.0
# 1013       934.0       415.0         2.8750            139600.0
# 1014      1506.0       492.0         1.7446             85200.0

# %%
#acces to a particular data
d["median_house_value"][500]
# Out:
# 154600.0

# %%
type(d), type(d["median_house_value"])
# Out:
# (pandas.core.frame.DataFrame, pandas.core.series.Series)

# %%
#to obtain only values to a easy processing
d["population"].unique()
# Out:
# array([ 1015.,  1129.,   333., ...,  1899.,   516.,  3546.])

# %%
d["median_house_value"].unique()
# Out:
# array([  66900.,   80100.,   85700., ...,  119700.,   75100.,   80500.])

# %%
d["median_house_value"].dtype, d["population"].dtype, d["latitude"].dtype
# Out:
# (dtype('float64'), dtype('float64'), dtype('float64'))

# %%
d.index
# Out:
# RangeIndex(start=0, stop=17000, step=1)

# %%
d[["population", "median_house_value"]].head()
# Out:
#    population  median_house_value
# 0      1015.0             66900.0
# 1      1129.0             80100.0
# 2       333.0             85700.0
# 3       515.0             73400.0
# 4       624.0             65500.0

# %% [markdown]
# **More and more information about the dataset can be easily obtained with Pandas**

# %%
# get the description of data
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17000 entries, 0 to 16999
# Data columns (total 9 columns):
# longitude             17000 non-null float64
# latitude              17000 non-null float64
# housing_median_age    17000 non-null float64
# total_rooms           17000 non-null float64
# total_bedrooms        17000 non-null float64
# population            17000 non-null float64
# households            17000 non-null float64
# median_income         17000 non-null float64
# median_house_value    17000 non-null float64
# dtypes: float64(9)
# memory usage: 1.2 MB

# %% [markdown]
# ## fixing data

# %%
d.columns
# Out:
# Index([u'longitude', u'latitude', u'housing_median_age', u'total_rooms',
#        u'total_bedrooms', u'population', u'households', u'median_income',
#        u'median_house_value'],
#       dtype='object')

# %%
#to add a new column in the dataset
d["new"] = population
d.head(15)
# Out:
#     longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0     -114.31     34.19                15.0       5612.0          1283.0
# 1     -114.47     34.40                19.0       7650.0          1901.0
# 2     -114.56     33.69                17.0        720.0           174.0
# 3     -114.57     33.64                14.0       1501.0           337.0
# 4     -114.57     33.57                20.0       1454.0           326.0
# 5     -114.58     33.63                29.0       1387.0           236.0
# 6     -114.58     33.61                25.0       2907.0           680.0
# 7     -114.59     34.83                41.0        812.0           168.0
# 8     -114.59     33.61                34.0       4789.0          1175.0
# 9     -114.60     34.83                46.0       1497.0           309.0
# 10    -114.60     33.62                16.0       3741.0           801.0
# 11    -114.60     33.60                21.0       1988.0           483.0
# 12    -114.61     34.84                48.0       1291.0           248.0
# 13    -114.61     34.83                31.0       2478.0           464.0
# 14    -114.63     32.76                15.0       1448.0           378.0
#
#     population  households  median_income  median_house_value         new
# 0       1015.0       472.0         1.4936             66900.0   1524690.0
# 1       1129.0       463.0         1.8200             80100.0  10157850.0
# 2        333.0       117.0         1.6509             85700.0     10000.0
# 3        515.0       226.0         3.1917             73400.0         NaN
# 4        624.0       262.0         1.9250             65500.0         NaN
# 5        671.0       239.0         3.3438             74000.0         NaN
# 6       1841.0       633.0         2.6768             82400.0         NaN
# 7        375.0       158.0         1.7083             48500.0         NaN
# 8       3134.0      1056.0         2.1782             58400.0         NaN
# 9        787.0       271.0         2.1908             48100.0         NaN
# 10      2434.0       824.0         2.6797             86500.0         NaN
# 11      1182.0       437.0         1.6250             62000.0         NaN
# 12       580.0       211.0         2.1571             48600.0         NaN
# 13      1346.0       479.0         3.2120             70400.0         NaN
# 14       949.0       300.0         0.8585             45000.0         NaN

# %%
#very important to clean values.
for col in d.columns:
    print col, np.sum(pd.isnull(d[col]))
# Out:
# longitude 0
# latitude 0
# housing_median_age 0
# total_rooms 0
# total_bedrooms 0
# population 0
# households 0
# median_income 0
# median_house_value 0
# new 16997

# %%
#Fill NA/NaN values using the specified method
d.new.fillna(population.mean(), inplace=True)

# %%
d.head(10)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
# 5    -114.58     33.63                29.0       1387.0           236.0
# 6    -114.58     33.61                25.0       2907.0           680.0
# 7    -114.59     34.83                41.0        812.0           168.0
# 8    -114.59     33.61                34.0       4789.0          1175.0
# 9    -114.60     34.83                46.0       1497.0           309.0
#
#    population  households  median_income  median_house_value           new
# 0      1015.0       472.0         1.4936             66900.0  1.524690e+06
# 1      1129.0       463.0         1.8200             80100.0  1.015785e+07
# 2       333.0       117.0         1.6509             85700.0  1.000000e+04
# 3       515.0       226.0         3.1917             73400.0  3.897513e+06
# 4       624.0       262.0         1.9250             65500.0  3.897513e+06
# 5       671.0       239.0         3.3438             74000.0  3.897513e+06
# 6      1841.0       633.0         2.6768             82400.0  3.897513e+06
# 7       375.0       158.0         1.7083             48500.0  3.897513e+06
# 8      3134.0      1056.0         2.1782             58400.0  3.897513e+06
# 9       787.0       271.0         2.1908             48100.0  3.897513e+06

# %% [markdown]
# ## Filtering data by boolean index

# %%
d[d.population>15000]
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2274     -117.42     33.35                14.0      25135.0          4819.0
# 2871     -117.74     33.89                 4.0      37937.0          5471.0
# 2969     -117.78     34.03                 8.0      32054.0          5290.0
# 3296     -117.87     34.04                 7.0      27700.0          4179.0
# 12772    -121.79     36.64                11.0      32627.0          6445.0
#
#        population  households  median_income  median_house_value           new
# 2274      35682.0      4769.0         2.5729            134400.0  3.897513e+06
# 2871      16122.0      5189.0         7.4947            366300.0  3.897513e+06
# 2969      15507.0      5050.0         6.0191            253900.0  3.897513e+06
# 3296      15037.0      4072.0         6.6288            339700.0  3.897513e+06
# 12772     28566.0      6082.0         2.3087            118800.0  3.897513e+06

# %%
 d[(d.population>15000) & (d.housing_median_age<14)]
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2871     -117.74     33.89                 4.0      37937.0          5471.0
# 2969     -117.78     34.03                 8.0      32054.0          5290.0
# 3296     -117.87     34.04                 7.0      27700.0          4179.0
# 12772    -121.79     36.64                11.0      32627.0          6445.0
#
#        population  households  median_income  median_house_value           new
# 2871      16122.0      5189.0         7.4947            366300.0  3.897513e+06
# 2969      15507.0      5050.0         6.0191            253900.0  3.897513e+06
# 3296      15037.0      4072.0         6.6288            339700.0  3.897513e+06
# 12772     28566.0      6082.0         2.3087            118800.0  3.897513e+06

# %% [markdown]
# ## Indexes
#  Series and DataFrame objects also define an index property that assigns an identifier value to each Series item or DataFrame row. Once created they do not change when data is reordered.

# %%
print(d.index)
print(type(d))
# Out:
# RangeIndex(start=0, stop=17000, step=1)
# <class 'pandas.core.frame.DataFrame'>

# %%
print(population.index)
print(type(population))
population
# Out:
# RangeIndex(start=0, stop=3, step=1)
# <class 'pandas.core.series.Series'>
# 0     1524690
# 1    10157850
# 2       10000
# dtype: int64

# %% [markdown]
#  to manually reorder the rows.

# %%
d.reindex([2, 0, 1])
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2    -114.56     33.69                17.0        720.0           174.0
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
#
#    population  households  median_income  median_house_value         new
# 2       333.0       117.0         1.6509             85700.0     10000.0
# 0      1015.0       472.0         1.4936             66900.0   1524690.0
# 1      1129.0       463.0         1.8200             80100.0  10157850.0

# %% [markdown]
# Reindexing is a great way to shuffle (randomize) a DataFrame

# %%
import numpy as np
d.reindex(np.random.permutation(d.index)).head()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 13238    -121.91     39.03                48.0       1096.0           218.0
# 14080    -122.06     37.99                17.0       1319.0           316.0
# 9651     -119.50     36.74                20.0       1089.0           208.0
# 16465    -122.61     38.23                18.0       2042.0           420.0
# 12525    -121.64     40.90                24.0       2237.0           434.0
#
#        population  households  median_income  median_house_value           new
# 13238       657.0       199.0         2.7841             65800.0  3.897513e+06
# 14080       384.0       269.0         1.8229            137500.0  3.897513e+06
# 9651        531.0       212.0         4.5938            106900.0  3.897513e+06
# 16465       914.0       400.0         2.9871            193800.0  3.897513e+06
# 12525       834.0       318.0         1.7538             90300.0  3.897513e+06

# %%
#sor values
d.sort_values(by="housing_median_age").head()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 13708    -122.00     38.23                 1.0       2062.0           343.0
# 10993    -120.93     37.65                 1.0       2254.0           328.0
# 1353     -117.17     34.12                 2.0       3867.0           573.0
# 8765     -118.61     34.38                 2.0       5989.0           883.0
# 8672     -118.56     34.42                 2.0        966.0           270.0
#
#        population  households  median_income  median_house_value           new
# 13708       872.0       268.0         5.2636            191300.0  3.897513e+06
# 10993       402.0       112.0         4.2500            189200.0  3.897513e+06
# 1353       1275.0       433.0         5.4138            164400.0  3.897513e+06
# 8765       1787.0       613.0         6.6916            329500.0  3.897513e+06
# 8672        233.0       169.0         1.9667            450000.0  3.897513e+06

# %%
#remove columns
del d['new']
d.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0

# %% [markdown]
# ## <span style="color:red"> 3. Plotting with matplotlib and pandas </span>
#
# #### Time series and Plotting

# %%
d.rolling(3).mean().head(10)
# Out:
#     longitude   latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0         NaN        NaN                 NaN          NaN             NaN
# 1         NaN        NaN                 NaN          NaN             NaN
# 2 -114.446667  34.093333           17.000000  4660.666667     1119.333333
# 3 -114.533333  33.910000           16.666667  3290.333333      804.000000
# 4 -114.566667  33.633333           17.000000  1225.000000      279.000000
# 5 -114.573333  33.613333           21.000000  1447.333333      299.666667
# 6 -114.576667  33.603333           24.666667  1916.000000      414.000000
# 7 -114.583333  34.023333           31.666667  1702.000000      361.333333
# 8 -114.586667  34.016667           33.333333  2836.000000      674.333333
# 9 -114.593333  34.423333           40.333333  2366.000000      550.666667
#
#     population  households  median_income  median_house_value
# 0          NaN         NaN            NaN                 NaN
# 1          NaN         NaN            NaN                 NaN
# 2   825.666667  350.666667       1.654833        77566.666667
# 3   659.000000  268.666667       2.220867        79733.333333
# 4   490.666667  201.666667       2.255867        74866.666667
# 5   603.333333  242.333333       2.820167        70966.666667
# 6  1045.333333  378.000000       2.648533        73966.666667
# 7   962.333333  343.333333       2.576300        68300.000000
# 8  1783.333333  615.666667       2.187767        63100.000000
# 9  1432.000000  495.000000       2.025767        51666.666667

# %% [markdown]
# ## Go to other dataset to see more functionalities of pandas
#
# Now, we are use a more specific dataset to see the pandas funtionalities in time. To see much better this kind of functionalities we will use a new dataset.
#
# Vamos a usar la recolección de un indice climático **AO (Oscilación Ártica)**, used to describe the states and climate changes.
#
# * Positive **AO+** when pressure differences is high,  the western winds from the Atlantic are intense over Europe and run through high latitudes, providing mild winters (inviernos templados) to the continent
#
# * Negative **AO-** when pressure differences is low, winters very cool...like in game of thrones!
#
#
# <img src="../imgs/aonao.png" style="width:500px;">
#
# We will convert in a pandas serie structure with monthly frequency

# %%
ao = np.loadtxt('../data/monthly_ao.txt')
print(ao.shape)
dates = pd.date_range('1950-01', periods=ao.shape[0], freq='M')
dates
# Out:
# (823, 3)
# DatetimeIndex(['1950-01-31', '1950-02-28', '1950-03-31', '1950-04-30',
#                '1950-05-31', '1950-06-30', '1950-07-31', '1950-08-31',
#                '1950-09-30', '1950-10-31',
#                ...
#                '2017-10-31', '2017-11-30', '2017-12-31', '2018-01-31',
#                '2018-02-28', '2018-03-31', '2018-04-30', '2018-05-31',
#                '2018-06-30', '2018-07-31'],
#               dtype='datetime64[ns]', length=823, freq='M')

# %%
AO = pd.Series(ao[:,2], index=dates)
AO.head()
AO.plot()

# %%
AO['1980':'1990'].plot()

# %%
AO.rolling(3).mean().head(10)
# Out:
# 1950-01-31         NaN
# 1950-02-28         NaN
# 1950-03-31    0.186124
# 1950-04-30    0.391261
# 1950-05-31    0.206183
# 1950-06-30    0.388416
# 1950-07-31   -0.064111
# 1950-08-31   -0.371640
# 1950-09-30   -0.431840
# 1950-10-31   -0.290647
# Freq: M, dtype: float64

# %%
AO.plot()

# %%
#SELECTING BY YEAR
AO['1960']
# Out:
# 1960-01-31   -2.484200
# 1960-02-29   -2.212400
# 1960-03-31   -1.624600
# 1960-04-30   -0.297310
# 1960-05-31   -0.857430
# 1960-06-30    0.054978
# 1960-07-31   -0.619060
# 1960-08-31   -1.007900
# 1960-09-30   -0.381640
# 1960-10-31   -1.187000
# 1960-11-30   -0.553230
# 1960-12-31   -0.342950
# Freq: M, dtype: float64

# %% [markdown]
# Pandas provide easy way to resample data to different time frequency.

# %%
AO_mm = AO.resample("A").mean()
AO_mm.plot(style='g--')

# %%
AO_mm = AO.resample("A").median()
AO_mm.plot()

# %%
AO_mm = AO.resample("A").apply(['mean', np.min, np.max])
AO_mm['1900':'2020'].plot(subplots=True)
AO_mm['1900':'2020'].plot()

# %% [markdown]
# oversampling

# %%
AO_res =AO.resample(pd.Timedelta("12h")).fillna(method="pad").head()
AO.plot()

# %%
AO.head()
# Out:
# 1950-01-31   -0.060310
# 1950-02-28    0.626810
# 1950-03-31   -0.008127
# 1950-04-30    0.555100
# 1950-05-31    0.071577
# Freq: M, dtype: float64

# %% [markdown]
# ## Building from different files

# %%
nao = np.loadtxt('../data/monthly_anao.txt')
dates_nao = pd.date_range('1950-01', periods=nao.shape[0], freq='M')

ao = np.loadtxt('../data/monthly_ao.txt')
dates = pd.date_range('1950-01', periods=ao.shape[0], freq='M')

AO = pd.Series(ao[:,2], index=dates)
NAO = pd.Series(nao[:,2], index=dates_nao)
NAO.index
# Out:
# DatetimeIndex(['1950-01-31', '1950-02-28', '1950-03-31', '1950-04-30',
#                '1950-05-31', '1950-06-30', '1950-07-31', '1950-08-31',
#                '1950-09-30', '1950-10-31',
#                ...
#                '2017-10-31', '2017-11-30', '2017-12-31', '2018-01-31',
#                '2018-02-28', '2018-03-31', '2018-04-30', '2018-05-31',
#                '2018-06-30', '2018-07-31'],
#               dtype='datetime64[ns]', length=823, freq='M')

# %%
aonao = pd.DataFrame({'AO' : AO, 'NAO' : NAO})
aonao.plot(subplots=True)

aonao.head()
# Out:
#                   AO   NAO
# 1950-01-31 -0.060310  0.92
# 1950-02-28  0.626810  0.40
# 1950-03-31 -0.008127 -0.36
# 1950-04-30  0.555100  0.73
# 1950-05-31  0.071577 -0.59

# %% [markdown]
# We can simply add column to the Data Frame:

# %%
aonao['Diff'] = aonao['AO'] - aonao['NAO']
aonao.head()
# Out:
#                   AO   NAO      Diff
# 1950-01-31 -0.060310  0.92 -0.980310
# 1950-02-28  0.626810  0.40  0.226810
# 1950-03-31 -0.008127 -0.36  0.351872
# 1950-04-30  0.555100  0.73 -0.174900
# 1950-05-31  0.071577 -0.59  0.661577

# %% [markdown]
# Rolling mean:

# %%
del aonao['Diff']

# %%
aonao.rolling(window=32, center=False).mean().plot(style='-g')

# %%
aonao.AO.rolling(window=120).corr(other=aonao.NAO).plot(style='-g')
aonao.corr()
# Out:
#            AO       NAO
# AO   1.000000  0.604537
# NAO  0.604537  1.000000

# %% [markdown]
# ## Building from arrays or lists

# %%
a = np.random.randint(10,size=(20,5))
a
# Out:
# array([[2, 9, 2, 8, 7],
#        [9, 4, 2, 6, 6],
#        [2, 4, 2, 9, 5],
#        [6, 8, 9, 4, 7],
#        [8, 4, 1, 5, 2],
#        [3, 7, 3, 0, 5],
#        [6, 4, 5, 7, 7],
#        [0, 6, 0, 5, 4],
#        [8, 0, 6, 1, 5],
#        [0, 5, 6, 0, 7],
#        [9, 8, 2, 1, 0],
#        [0, 5, 6, 4, 7],
#        [8, 6, 4, 4, 3],
#        [0, 5, 5, 1, 6],
#        [2, 1, 0, 9, 3],
#        [0, 5, 0, 5, 7],
#        [0, 0, 9, 2, 7],
#        [0, 2, 8, 5, 0],
#        [8, 8, 2, 4, 9],
#        [7, 5, 4, 4, 4]])

# %%
k = pd.DataFrame(a, columns=["uno", "dos", "tres", "cuatro", "cinco"], index=range(10,10+len(a)))
k
# Out:
#     uno  dos  tres  cuatro  cinco
# 10    2    9     2       8      7
# 11    9    4     2       6      6
# 12    2    4     2       9      5
# 13    6    8     9       4      7
# 14    8    4     1       5      2
# 15    3    7     3       0      5
# 16    6    4     5       7      7
# 17    0    6     0       5      4
# 18    8    0     6       1      5
# 19    0    5     6       0      7
# 20    9    8     2       1      0
# 21    0    5     6       4      7
# 22    8    6     4       4      3
# 23    0    5     5       1      6
# 24    2    1     0       9      3
# 25    0    5     0       5      7
# 26    0    0     9       2      7
# 27    0    2     8       5      0
# 28    8    8     2       4      9
# 29    7    5     4       4      4

# %% [markdown]
# ## More about plotting

# %%
d.plot(figsize=(15,3))

# %%
attributes = [ "median_income", "total_rooms", "housing_median_age"]
d[attributes].plot(figsize=(15,3))
#pd.plotting.scatter_matrix(d[attributes], figsize=(12,8))

# %%
d.total_rooms.plot()

# %%
plt.scatter(d.median_house_value, d.population)

# %%
attributes = ["median_house_value", "median_income", "total_rooms", "housing_median_age"]
pd.plotting.scatter_matrix(d[attributes], figsize=(12,8))

#pd.plotting.scatter_matrix(d, figsize=(10,10));
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f2f33d33d10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2f33cb0d50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2f33c7d710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2f33c491d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f2f33c0bb50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2f35de8bd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2f33fde8d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2f3589f2d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f2f35547c10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2f358af9d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2f35892950>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2f33bc3190>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f2f33bc83d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2f33b7f4d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2f33f99c10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2f33afb0d0>]], dtype=object)

# %%
d.plot(kind="scatter", x="median_income", y="median_house_value", alpha=0.1)

# %%
d.plot(kind="scatter", x="longitude", y="latitude", alpha=0.4, s=d["population"]/100,
             label="population", c="median_house_value", cmap=plt.get_cmap("jet"), colorbar=True,
            )
plt.legend()
d.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0

# %% [markdown]
# ## grouping

# %%
aonao["month"] = [i.month for i in aonao.index]
aonao.head()
# Out:
#                   AO   NAO  month
# 1950-01-31 -0.060310  0.92      1
# 1950-02-28  0.626810  0.40      2
# 1950-03-31 -0.008127 -0.36      3
# 1950-04-30  0.555100  0.73      4
# 1950-05-31  0.071577 -0.59      5

# %%
aonao.groupby("month").max()
# Out:
#             AO     NAO
# month
# 1      3.49530  1.7887
# 2      3.40160  2.0000
# 3      2.99000  1.8500
# 4      2.27480  2.4775
# 5      1.39110  2.6300
# 6      1.60630  1.6000
# 7      0.86555  1.9000
# 8      1.09780  1.9200
# 9      1.27830  2.0700
# 10     1.67580  1.9300
# 11     2.46950  3.0400
# 12     2.28170  2.5213

# %%
aonao.groupby("month").count()
# Out:
#        AO  NAO
# month
# 1      69   69
# 2      69   69
# 3      69   69
# 4      69   69
# 5      69   69
# 6      69   69
# 7      69   69
# 8      68   68
# 9      68   68
# 10     68   68
# 11     68   68
# 12     68   68

# %% [markdown]
# #Exercises

# %% [markdown]
# ## Data Loading and Inspection
# Load the Iris dataset from a CSV file into a Pandas DataFrame. The dataset URL is https://raw.githubusercontent.com/uiuc-cse/data-fa14/gh-pages/data/iris.csv.
#
# Display the first 5 rows of the dataset.
# Use the .describe() method to display the summary statistics of the dataset.

# %% [markdown]
# ## Data Cleaning
# Check for any missing values in the Iris dataset. If there are any, fill them with the column's mean value.
# Find and remove any duplicate rows.

# %% [markdown]
# ## Filtering Data
# From the Iris dataset, filter out only those rows that have a petal length (petal_length) greater than 1.5 and a sepal width (sepal_width) less than 3.0.

# %% [markdown]
# ## Data Transformation
# Create a new column in the Iris dataset called sepal_area by multiplying the sepal length (sepal_length) and sepal width (sepal_width).

# %% [markdown]
# ## Grouping and Aggregation
# Group the Iris dataset by the species column and calculate the mean of all numeric columns for each species.

# %% [markdown]
# # Referencias
#
# [1] official panda doc sites:http://pandas.pydata.org/pandas-docs/stable/index.html
#
# [2] Description of a dataset: https://www.kaggle.com/camnugent/california-housing-prices

# %% [markdown]
# ![Diagrama sin título.drawio.jpg](data:image/jpeg;base64,...)
